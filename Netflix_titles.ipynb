# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
df.tail()
# Out:
#        show_id     type                                        title  \
# 6230  80000063  TV Show                                 Red vs. Blue
# 6231  70286564  TV Show                                        Maron
# 6232  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6233  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6234  70153404  TV Show                                      Friends
#
#         director                                               cast  \
# 6230  Marc Maron  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...
# 6231  Marc Maron  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...
# 6232  Marc Maron                                                NaN
# 6233  Marc Maron  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...
# 6234  Marc Maron  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...
#
#              country date_added  release_year rating    duration  \
# 6230   United States        NaT          2015     NR  13 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6235 entries, 0 to 6234
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6235 non-null   int64
#  1   type          6235 non-null   object
#  2   title         6235 non-null   object
#  3   director      4266 non-null   object
#  4   cast          5665 non-null   object
#  5   country       5759 non-null   object
#  6   date_added    6224 non-null   object
#  7   release_year  6235 non-null   int64
#  8   rating        6225 non-null   object
#  9   duration      6235 non-null   object
#  10  listed_in     6235 non-null   object
#  11  description   6235 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.7+ KB

# %%
df['date_added'].head(10)
# Out:
# 0    September 9, 2019
# 1    September 9, 2016
# 2    September 8, 2018
# 3    September 8, 2018
# 4    September 8, 2017
# 5    September 8, 2017
# 6    September 8, 2017
# 7    September 8, 2017
# 8    September 8, 2017
# 9    September 8, 2017
# Name: date_added, dtype: object

# %%
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df['date_added'].head(10)
# Out:
# 0   2019-09-09
# 1   2016-09-09
# 2   2018-09-08
# 3   2018-09-08
# 4   2017-09-08
# 5   2017-09-08
# 6   2017-09-08
# 7   2017-09-08
# 8   2017-09-08
# 9   2017-09-08
# Name: date_added, dtype: datetime64[ns]

# %%
df['date_added'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 6234 entries, 0 to 6234
# Series name: date_added
# Non-Null Count  Dtype
# --------------  -----
# 6223 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 226.4 KB

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df.loc[df['show_id']==70286564]
# Out:
#        show_id     type  title director  \
# 6231  70286564  TV Show  Maron      NaN
#
#                                                    cast        country  \
# 6231  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...  United States
#
#      date_added  release_year rating   duration    listed_in  \
# 6231        NaT          2016  TV-MA  4 Seasons  TV Comedies
#
#                                             description
# 6231  Marc Maron stars as Marc Maron, who interviews...

# %%
df.loc[df['director'].isnull()] #ngecek kayak where di SQL
# Out:
#        show_id     type                                        title director  \
# 1     80117401    Movie                   Jandino: Whatever it Takes      NaN
# 2     70234439  TV Show                           Transformers Prime      NaN
# 3     80058654  TV Show             Transformers: Robots in Disguise      NaN
# 5     80163890  TV Show                                      Apaches      NaN
# 8     80117902  TV Show                                 Fire Chasers      NaN
# ...        ...      ...                                          ...      ...
# 6230  80000063  TV Show                                 Red vs. Blue      NaN
# 6231  70286564  TV Show                                        Maron      NaN
# 6232  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends      NaN
# 6233  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6234  70153404  TV Show                                      Friends      NaN
#
# ...

# %%
df.loc[df['show_id']==70286564,'director'].replace(to_replace=np.nan,
           value="Marc Maron")
# Out:
# 6231    Marc Maron
# Name: director, dtype: object

# %%
df.loc[df['show_id']==70286564]
# Out:
#        show_id     type  title    director  \
# 6231  70286564  TV Show  Maron  Marc Maron
#
#                                                    cast        country  \
# 6231  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...  United States
#
#      date_added  release_year rating   duration    listed_in  \
# 6231        NaT          2016  TV-MA  4 Seasons  TV Comedies
#
#                                             description
# 6231  Marc Maron stars as Marc Maron, who interviews...

# %%
df.replace({pd.NaT: "2022-10-22"}, inplace=True) #ganti tanggal nat ke tanggal sekarang

# %%
df.loc[df['show_id']==70286564]
# Out:
#        show_id     type  title    director  \
# 6231  70286564  TV Show  Maron  Marc Maron
#
#                                                    cast        country  \
# 6231  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...  United States
#
#       date_added  release_year rating   duration    listed_in  \
# 6231  2022-10-22          2016  TV-MA  4 Seasons  TV Comedies
#
#                                             description
# 6231  Marc Maron stars as Marc Maron, who interviews...

# %%
df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                Marc Maron
# 2                Marc Maron
# 3                Marc Maron
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country  date_added  release_year  \
# ...
